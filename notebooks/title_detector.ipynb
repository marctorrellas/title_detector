# %%
import warnings
import logging
import re
from functools import partial

# External imports
import pandas as pd, numpy as np, seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import joblib
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.metrics import (
    precision_recall_curve, 
    roc_curve,
    fbeta_score,
    confusion_matrix,
    precision_score,
    recall_score,
    make_scorer
)
from sklearn.exceptions import UndefinedMetricWarning
from xgboost import XGBClassifier

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from lib.jupyter_helpers import notebook_setup
notebook_setup()

log = logging.getLogger(__name__)
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(message)s", datefmt="%Y-%m-%d %H:%M:%S"
)

# warnings.filterwarnings("ignore", category=DeprecationWarning)
# warnings.filterwarnings("ignore", category=UndefinedMetricWarning)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>     .output {          display: block;          align-items: center;          text-align: center;     }     .jp-Stdin-input {          width: 90%     }</style>

# %%
path = "../title_detector/sample/train_sections_data.csv"
df = pd.read_csv(path, encoding="latin1")
import re
def to_snake(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()
df.columns = [to_snake(col) for col in df.columns]
df.head(2)
# Out:
#                                                 text  is_bold  is_italic  \
# 0  NOTES TO THE ACCOUNTS FOR THE 52 WEEK PERIOD E...     True      False
# 1                             DERIVATIVE INSTRUMENTS    False      False
#
#    is_underlined  left  right   top  bottom        font_type  label  \
# 0          False  49.5  544.0  67.3    96.1  New Times Roman      1
# 1          False  41.5  140.2  49.0    54.7  New Times Roman      1
#
#    unnamed: 10  unnamed: 11 unnamed: 12
# 0          NaN          NaN         NaN
# 1          NaN          NaN         NaN

# %%
df.describe(include="all")
# Out:
#          Text IsBold IsItalic IsUnderlined          Left         Right  \
# count   14215  14215    14215        14215  14215.000000  14215.000000
# unique  11421      2        2            2           NaN           NaN
# top           False    False        False           NaN           NaN
# freq      632  10849    13159        14095           NaN           NaN
# mean      NaN    NaN      NaN          NaN     71.077418    451.751952
# std       NaN    NaN      NaN          NaN     56.290498    270.240403
# min       NaN    NaN      NaN          NaN     28.300000     31.800000
# 25%       NaN    NaN      NaN          NaN     33.100000    177.050000
# 50%       NaN    NaN      NaN          NaN     51.000000    523.500000
# 75%       NaN    NaN      NaN          NaN     96.300000    728.100000
# max       NaN    NaN      NaN          NaN    783.500000    814.400000
#
#                  Top        Bottom         FontType         Label  \
# count   14215.000000  14215.000000            14215  14215.000000
# unique           NaN           NaN                1           NaN
# top              NaN           NaN  New Times Roman           NaN
# freq             NaN           NaN            14215           NaN
# mean      285.437557    317.711894              NaN      0.259937
# std       196.358206    198.412240              NaN      0.438615
# min        19.900000     35.500000              NaN      0.000000
# 25%       139.300000    174.800000              NaN      0.000000
# 50%       250.900000    286.200000              NaN      0.000000
# 75%       375.700000    408.900000              NaN      1.000000
# max      1532.437194   1540.537194              NaN      1.000000
#
#         Unnamed: 10  Unnamed: 11 Unnamed: 12
# count           0.0          0.0           1
# unique          NaN          NaN           1
# top             NaN          NaN           .
# freq            NaN          NaN           1
# mean            NaN          NaN         NaN
# std             NaN          NaN         NaN
# min             NaN          NaN         NaN
# 25%             NaN          NaN         NaN
# 50%             NaN          NaN         NaN
# 75%             NaN          NaN         NaN
# max             NaN          NaN         NaN

# %% [markdown]
# We can drop FontType as it has only one unique value

# %%
df.drop("FontType", axis=1, inplace=True)
df = df.iloc[:, :-3]
df.head()
# Out:
#                                                 Text  IsBold  IsItalic  \
# 0  NOTES TO THE ACCOUNTS FOR THE 52 WEEK PERIOD E...    True     False
# 1                             DERIVATIVE INSTRUMENTS   False     False
# 2                                                 -6   False     False
# 3  The following performance graph and related in...   False     False
# 4  Typical service offerings include supply chain...   False     False
#
#    IsUnderlined   Left  Right    Top  Bottom  Label
# 0         False   49.5  544.0   67.3    96.1      1
# 1         False   41.5  140.2   49.0    54.7      1
# 2         False  113.5  122.2  409.3   414.9      0
# 3         False  112.9  706.9  339.0   360.3      0
# 4         False   33.1  808.5  328.2   369.9      0

# %%
def to_snake(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()
df.columns = [to_snake(col) for col in df.columns]
df.columns
# Out:
# Index(['text', 'is_bold', 'is_italic', 'is_underlined', 'left', 'right', 'top',
#        'bottom', 'label'],
#       dtype='object')

# %% [markdown]
# sns.set_style("ticks")
# sns.pairplot(
#     df.drop("text", axis=1),
#     hue = 'label',
#     diag_kind = "kde",
#     kind = "scatter",
#     palette = "husl",
#     height=4
# )
# plt.show()

# %%
df.head()
# Out:
#                                                 text  is_bold  is_italic  \
# 0  NOTES TO THE ACCOUNTS FOR THE 52 WEEK PERIOD E...     True      False
# 1                             DERIVATIVE INSTRUMENTS    False      False
# 2                                                 -6    False      False
# 3  The following performance graph and related in...    False      False
# 4  Typical service offerings include supply chain...    False      False
#
#    is_underlined   left  right    top  bottom  label
# 0          False   49.5  544.0   67.3    96.1      1
# 1          False   41.5  140.2   49.0    54.7      1
# 2          False  113.5  122.2  409.3   414.9      0
# 3          False  112.9  706.9  339.0   360.3      0
# 4          False   33.1  808.5  328.2   369.9      0

# %% [markdown]
# ### Simple preprocessing: remove non-ascii characters

# %%
df["text"] = df["text"].str.replace(r'[^\x00-\x7F]+', ' ')

# %% [markdown]
# ### Get feature-labels

# %%
X = df.drop("label", axis=1)
y = df["label"]

# %%
y.value_counts()
# Out:
# 0    10520
# 1     3695
# Name: label, dtype: int64

# %% [markdown]
# ## Models

# %% [markdown]
# 1) Baselines: text classification based on feature engineering from the whole text, and using a classical classifier, e.g. SVM, RandomForest, LogisticRegression
# * Len(text)
# * Are they all capitals
# * Tf-idf
# * LDA?
#
# 2) LSTM-based: FastAI?
#
# 3) BertForTextClassification: BERT model with a linear layer on top of the pooled output.

# %%
pipe = Pipeline([
    # the classifier params will be populated by the param_grid
    ('scaling', MinMaxScaler()),
    ('classifier', SVC()),
])
my_cross_validate(pipe, X.drop("text", axis=1), y, scoring = scoring)
# Out:
# precision --> Train: 0.924, Test: 0.922,
# recall --> Train: 0.884, Test: 0.88,
# fbeta --> Train: 0.903, Test: 0.9,

# %%
pipe = Pipeline([
    # the classifier params will be populated by the param_grid
    ('scaling', MinMaxScaler()),
    ('classifier', RandomForestClassifier())
])
my_cross_validate(pipe, X.drop("text", axis=1), y, scoring = scoring)
# Out:
# precision --> Train: 0.998, Test: 0.957,
# recall --> Train: 0.994, Test: 0.934,
# fbeta --> Train: 0.996, Test: 0.945,

# %%
pipe = Pipeline([
    # the reduce_dim stage is populated by the param_grid
    ('scaling', MinMaxScaler()),
    ('classifier', SVC()),
])
param_grid = []
for kernel in ['rbf', 'linear']:
    gamma_dict = {'gamma': [1e-2, 1e-4, 'auto']} if kernel == "rbf" else {}
    param_grid.append({'kernel': [kernel],
                       "random_state": [1],
                       'C': [0.1, 1, 10, 100], 
                       "class_weight": ["balanced"],
                       **gamma_dict,
                      })
for idx, sub_param_grid in enumerate(param_grid):
    param_grid[idx] = {f"classifier__{key}": value for key, value in sub_param_grid.items()}
model = grid_search_algo(
    pipe, param_grid, X.drop("text", axis=1), y, scoring=scoring, refit=False,
)
analyse_grid_search(model)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=3)]: Done 160 out of 160 | elapsed:  6.8min finished
#                                       11        8         5         6   \
# mean_test_recall                0.926114  0.926114  0.926114  0.926114
# mean_test_precision             0.907143  0.900718   0.89573  0.884818
# mean_test_fbeta                 0.916444  0.913147  0.910589  0.904931
# mean_train_recall               0.926116  0.926116  0.926116  0.926116
# mean_train_precision            0.908473  0.900951  0.895945  0.884696
# mean_train_fbeta                0.917208  0.913359  0.910779  0.904932
# param_classifier__C                  100        10         1        10
# param_classifier__class_weight  balanced  balanced  balanced  balanced
# param_classifier__gamma             auto      auto      auto      0.01
# param_classifier__kernel             rbf       rbf       rbf       rbf
# param_classifier__random_state         1         1         1         1
# mean_fit_time                    3.92587   2.49534   1.61372   1.84123
#
#                                       9         12        13        14  \
# mean_test_recall                0.926114  0.926114  0.926114  0.926114
# mean_test_precision             0.884818  0.884818  0.884818  0.884818
# mean_test_fbeta                 0.904931  0.904931  0.904931  0.904931
# mean_train_recall               0.926116  0.926116  0.926116  0.926116
# mean_train_precision            0.884696  0.884696  0.884696  0.884696
# mean_train_fbeta                0.904932  0.904932  0.904932  0.904932
# param_classifier__C                  100       0.1         1        10
# param_classifier__class_weight  balanced  balanced  balanced  balanced
# param_classifier__gamma             0.01       NaN       NaN       NaN
# param_classifier__kernel             rbf    linear    linear    linear
# param_classifier__random_state         1         1         1         1
# mean_fit_time                    2.35977  0.545371  0.571876  0.635948
#
#                                       15        2         3         10  \
# mean_test_recall                0.926114  0.924488  0.919615  0.919615
# mean_test_precision             0.884818  0.884858  0.886645  0.886645
# mean_test_fbeta                 0.904931  0.904169  0.902757  0.902757
# mean_train_recall               0.926116  0.925545  0.919621  0.919621
# mean_train_precision            0.884696  0.884941  0.886514  0.886514
# mean_train_fbeta                0.904932  0.904785  0.902763  0.902763
# param_classifier__C                  100       0.1         1       100
# param_classifier__class_weight  balanced  balanced  balanced  balanced
# param_classifier__gamma              NaN      auto      0.01    0.0001
# param_classifier__kernel          linear       rbf       rbf       rbf
# param_classifier__random_state         1         1         1         1
# mean_fit_time                    1.07501   1.63586   1.82231   1.40273
#
#                                       0         4         7         1
# mean_test_recall                0.850331  0.850331  0.850331         1
# mean_test_precision             0.933542  0.933542  0.933542  0.259937
# mean_test_fbeta                 0.889907  0.889907  0.889907  0.412618
# mean_train_recall               0.850338  0.850338  0.850338         1
# mean_train_precision            0.933453  0.933453  0.933453  0.259937
# mean_train_fbeta                0.889958  0.889958  0.889958  0.412619
# param_classifier__C                  0.1         1        10       0.1
# param_classifier__class_weight  balanced  balanced  balanced  balanced
# param_classifier__gamma             0.01    0.0001    0.0001    0.0001
# param_classifier__kernel             rbf       rbf       rbf       rbf
# param_classifier__random_state         1         1         1         1
# mean_fit_time                    6.46874    11.566   3.43896   12.0095
#                            max       min
# mean_test_recall      1.000000  0.850331
# mean_test_precision   0.933542  0.259937
# mean_test_fbeta       0.916444  0.412618
# mean_train_recall     1.000000  0.850338
# mean_train_precision  0.933453  0.259937
# mean_train_fbeta      0.917208  0.412619

# %%
pipe = Pipeline([
    # the reduce_dim stage is populated by the param_grid
    ('scaling', MinMaxScaler()),
    ('classifier', RandomForestClassifier()),
])
param_grid = {
        "n_estimators": [100],
        "min_samples_split": [2, 5, 7],
        "max_features": ["sqrt", None],
        "max_depth": [3, 5, 10],
        "random_state": [1],
        "class_weight": ["balanced"]
    }
param_grid = {f"classifier__{key}": value for key, value in param_grid.items()}
result = grid_search_algo(
    pipe, param_grid, X.drop("text", axis=1), y, scoring=scoring, refit=False,
)
analyse_grid_search(result)
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:   21.5s
# [Parallel(n_jobs=3)]: Done 180 out of 180 | elapsed:  2.2min finished
#                                            15        16        17        12  \
# mean_test_recall                     0.959941  0.960754  0.961025  0.958318
# mean_test_precision                  0.939201  0.936779  0.935077  0.930451
# mean_test_fbeta                      0.949402   0.94855  0.947815  0.944142
# mean_train_recall                    0.980815  0.979371  0.977507  0.972515
# mean_train_precision                 0.958649  0.955049  0.952281   0.94548
# mean_train_fbeta                     0.969604  0.967057  0.964729  0.958806
# param_classifier__class_weight       balanced  balanced  balanced  balanced
# param_classifier__max_depth                10        10        10        10
# param_classifier__max_features           None      None      None      sqrt
# param_classifier__min_samples_split         2         5         7         2
# param_classifier__n_estimators            100       100       100       100
# param_classifier__random_state              1         1         1         1
# mean_fit_time                         3.28369   3.31653   3.28658   1.35778
#
#                                            13        14        10        11  \
# mean_test_recall                     0.959129  0.959402  0.949928  0.949928
# mean_test_precision                  0.928564  0.927618  0.919225  0.919225
# mean_test_fbeta                      0.943557  0.943202  0.934265  0.934265
# mean_train_recall                    0.971703  0.971373  0.952398  0.952248
# mean_train_precision                 0.941966  0.941041  0.922551  0.922433
# mean_train_fbeta                     0.956602  0.955965  0.937235  0.937101
# param_classifier__class_weight       balanced  balanced  balanced  balanced
# param_classifier__max_depth                10        10         5         5
# param_classifier__max_features           sqrt      sqrt      None      None
# param_classifier__min_samples_split         5         7         5         7
# param_classifier__n_estimators            100       100       100       100
# param_classifier__random_state              1         1         1         1
# mean_fit_time                         1.33348   1.33686   2.13477    2.1148
#
#                                            9         8         7         6   \
# mean_test_recall                     0.949928  0.938286  0.938016  0.937746
# mean_test_precision                  0.919225  0.910085  0.910068  0.910267
# mean_test_fbeta                      0.934265   0.92388  0.923741  0.923715
# mean_train_recall                    0.952428  0.941182  0.941121  0.941061
# mean_train_precision                 0.922581  0.913909  0.913746  0.913843
# mean_train_fbeta                     0.937265  0.927337  0.927223  0.927246
# param_classifier__class_weight       balanced  balanced  balanced  balanced
# param_classifier__max_depth                 5         5         5         5
# param_classifier__max_features           None      sqrt      sqrt      sqrt
# param_classifier__min_samples_split         2         7         5         2
# param_classifier__n_estimators            100       100       100       100
# param_classifier__random_state              1         1         1         1
# mean_fit_time                         2.18322  0.998131  0.926491  0.944078
#
#                                            1         2         0         5   \
# mean_test_recall                     0.937744  0.937744  0.937744  0.917989
# mean_test_precision                  0.899015  0.899015  0.899015  0.914648
# mean_test_fbeta                      0.917849  0.917849  0.917849  0.916228
# mean_train_recall                    0.939047  0.939047  0.939047  0.918328
# mean_train_precision                 0.899799  0.899799  0.899799  0.914836
# mean_train_fbeta                        0.919     0.919     0.919  0.916578
# param_classifier__class_weight       balanced  balanced  balanced  balanced
# param_classifier__max_depth                 3         3         3         3
# param_classifier__max_features           sqrt      sqrt      sqrt      None
# param_classifier__min_samples_split         5         7         2         7
# param_classifier__n_estimators            100       100       100       100
# param_classifier__random_state              1         1         1         1
# mean_fit_time                        0.714171  0.711765  0.713103   1.41234
#
#                                            4         3
# mean_test_recall                     0.917989  0.917989
# mean_test_precision                  0.914648  0.914648
# mean_test_fbeta                      0.916228  0.916228
# mean_train_recall                    0.918328  0.918328
# mean_train_precision                 0.914836  0.914836
# mean_train_fbeta                     0.916578  0.916578
# param_classifier__class_weight       balanced  balanced
# param_classifier__max_depth                 3         3
# param_classifier__max_features           None      None
# param_classifier__min_samples_split         5         2
# param_classifier__n_estimators            100       100
# param_classifier__random_state              1         1
# mean_fit_time                         1.40726   1.45154
#                            max       min
# mean_test_recall      0.961025  0.917989
# mean_test_precision   0.939201  0.899015
# mean_test_fbeta       0.949402  0.916228
# mean_train_recall     0.980815  0.918328
# mean_train_precision  0.958649  0.899799
# mean_train_fbeta      0.969604  0.916578

# %% [markdown]
# ## Add text lenght info

# %%
# TODO: do this more efficient? with .str. in pandas?
df["char_length"] = df.text.map(len)

# %%
import spacy
from tqdm import tqdm_notebook as tqdm

# %%
# TODO: load lg?
nlp = spacy.load("en_core_web_sm", disable=["parser", "tagger", "ner"])

# %%
documents = []
for doc in tqdm(df["text"]):
    documents.append(nlp(doc))
# Out:
# HBox(children=(IntProgress(value=0, max=14215), HTML(value='')))

# %%
# TODO: do this more efficient
df["token_length"] = list(map(len, documents))

# %%
df.head()
# Out:
#                                                 text  is_bold  is_italic  \
# 0  NOTES TO THE ACCOUNTS FOR THE 52 WEEK PERIOD E...     True      False
# 1                             DERIVATIVE INSTRUMENTS    False      False
# 2                                                 -6    False      False
# 3  The following performance graph and related in...    False      False
# 4  Typical service offerings include supply chain...    False      False
#
#    is_underlined   left  right    top  bottom  label  char_length  \
# 0          False   49.5  544.0   67.3    96.1      1           66
# 1          False   41.5  140.2   49.0    54.7      1           22
# 2          False  113.5  122.2  409.3   414.9      0            2
# 3          False  112.9  706.9  339.0   360.3      0          525
# 4          False   33.1  808.5  328.2   369.9      0         1061
#
#    token_length
# 0            13
# 1             2
# 2             1
# 3            99
# 4           164

# %%
pipe = Pipeline([
    # the reduce_dim stage is populated by the param_grid
    ('scaling', MinMaxScaler()),
    ('classifier', RandomForestClassifier()),
])
param_grid = {
        "n_estimators": [100, 300],
        "min_samples_split": [2, 5, 7],
        "max_features": ["sqrt", None],
        "max_depth": [3, 5, 10, 25],
        "random_state": [1],
        "class_weight": ["balanced"]
    }
param_grid = {f"classifier__{key}": value for key, value in param_grid.items()}
result = grid_search_algo(
    pipe, param_grid, X.drop("text", axis=1), y, scoring=scoring, refit=False,
)
analyse_grid_search(result)
# Out:
# Fitting 10 folds for each of 48 candidates, totalling 480 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:   36.7s
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=3)]: Done 444 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=3)]: Done 480 out of 480 | elapsed: 14.4min finished
#                                              45          43          44  \
# mean_test_recall                       0.962926    0.956429    0.962383
# mean_test_precision                    0.949667    0.955204    0.948868
# mean_test_fbeta                        0.956201    0.955773    0.955539
# std_test_fbeta                       0.00382169  0.00391429  0.00348275
# mean_train_recall                      0.998827           1    0.998226
# mean_train_precision                   0.987104    0.999459     0.98651
# mean_train_fbeta                        0.99293    0.999729    0.992333
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          25          25
# param_classifier__max_features             None        None        None
# param_classifier__min_samples_split           5           2           5
# param_classifier__n_estimators              300         300         100
# param_classifier__random_state                1           1           1
# mean_fit_time                            12.563     11.5123     4.70316
#
#                                              42          47          46  \
# mean_test_recall                       0.954806    0.965091    0.965092
# mean_test_precision                    0.955628    0.942976    0.942722
# mean_test_fbeta                        0.955183    0.953867    0.953737
# std_test_fbeta                       0.00381343  0.00404722  0.00403222
# mean_train_recall                       0.99997    0.996031     0.99561
# mean_train_precision                   0.999459    0.976533    0.976582
# mean_train_fbeta                       0.999714    0.986185    0.986004
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          25          25
# param_classifier__max_features             None        None        None
# param_classifier__min_samples_split           2           7           7
# param_classifier__n_estimators              100         300         100
# param_classifier__random_state                1           1           1
# mean_fit_time                           3.86426     11.5066      4.0059
#
#                                              38          39          40  \
# mean_test_recall                       0.959405    0.959132     0.96238
# mean_test_precision                    0.948185    0.947909     0.94405
# mean_test_fbeta                        0.953736    0.953468    0.953107
# std_test_fbeta                       0.00562283  0.00535055  0.00503966
# mean_train_recall                      0.998617    0.999158    0.996211
# mean_train_precision                   0.981414    0.981539    0.970674
# mean_train_fbeta                        0.98994     0.99027    0.983276
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          25          25
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           5           5           7
# param_classifier__n_estimators              100         300         100
# param_classifier__random_state                1           1           1
# mean_fit_time                           1.58206     4.75953     1.61441
#
#                                              36          41         37  \
# mean_test_recall                       0.951011     0.96265     0.9502
# mean_test_precision                    0.954918    0.942824   0.954102
# mean_test_fbeta                        0.952941    0.952608   0.952136
# std_test_fbeta                       0.00608773  0.00501931  0.0069093
# mean_train_recall                             1    0.996752          1
# mean_train_precision                   0.999459    0.970178   0.999459
# mean_train_fbeta                       0.999729    0.983285   0.999729
# param_classifier__class_weight         balanced    balanced   balanced
# param_classifier__max_depth                  25          25         25
# param_classifier__max_features             sqrt        sqrt       sqrt
# param_classifier__min_samples_split           2           7          2
# param_classifier__n_estimators              100         300        300
# param_classifier__random_state                1           1          1
# mean_fit_time                           1.61751     4.65426    4.67015
#
#                                             31          33         30  \
# mean_test_recall                      0.961031    0.961573   0.960759
# mean_test_precision                   0.938041    0.936351   0.936039
# mean_test_fbeta                       0.949353    0.948746   0.948195
# std_test_fbeta                       0.0046257  0.00561403  0.0041245
# mean_train_recall                     0.980274    0.978469   0.980183
# mean_train_precision                  0.958377    0.954479   0.957726
# mean_train_fbeta                        0.9692    0.966324   0.968822
# param_classifier__class_weight        balanced    balanced   balanced
# param_classifier__max_depth                 10          10         10
# param_classifier__max_features            None        None       None
# param_classifier__min_samples_split          2           5          2
# param_classifier__n_estimators             300         300        100
# param_classifier__random_state               1           1          1
# mean_fit_time                          10.3554     10.0486    3.63906
#
#                                              32         35          34  \
# mean_test_recall                       0.961843   0.962655    0.962655
# mean_test_precision                    0.934892   0.933496    0.933222
# mean_test_fbeta                        0.948129     0.9478    0.947665
# std_test_fbeta                       0.00446333  0.0054576  0.00496695
# mean_train_recall                       0.97868   0.976695    0.976966
# mean_train_precision                   0.953793   0.951437    0.951454
# mean_train_fbeta                       0.966073   0.963899    0.964038
# param_classifier__class_weight         balanced   balanced    balanced
# param_classifier__max_depth                  10         10          10
# param_classifier__max_features             None       None        None
# param_classifier__min_samples_split           5          7           7
# param_classifier__n_estimators              100        300         100
# param_classifier__random_state                1          1           1
# mean_fit_time                           3.32539    12.0564     3.39398
#
#                                              25          27          29  \
# mean_test_recall                       0.959406    0.960219    0.959947
# mean_test_precision                    0.932736    0.930574    0.930327
# mean_test_fbeta                        0.945856    0.945135    0.944877
# std_test_fbeta                       0.00603134  0.00589709  0.00596707
# mean_train_recall                      0.973177    0.972155    0.971944
# mean_train_precision                   0.945817    0.942153    0.940551
# mean_train_fbeta                       0.959301    0.956918    0.955989
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  10          10          10
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           2           5           7
# param_classifier__n_estimators              300         300         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           4.23429     4.15278     4.25852
#
#                                              28          24          26  \
# mean_test_recall                       0.960218    0.957783    0.959407
# mean_test_precision                    0.929634    0.931672    0.929329
# mean_test_fbeta                        0.944641     0.94451    0.944091
# std_test_fbeta                       0.00690321  0.00616846  0.00590572
# mean_train_recall                      0.972004    0.972966    0.972125
# mean_train_precision                   0.940117    0.945254    0.941739
# mean_train_fbeta                       0.955794    0.958909     0.95669
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  10          10          10
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           7           2           5
# param_classifier__n_estimators              100         100         100
# param_classifier__random_state                1           1           1
# mean_fit_time                           1.38026     1.61512      1.3489
#
#                                             19         21          18  \
# mean_test_recall                      0.950206   0.950206    0.949665
# mean_test_precision                    0.91947    0.91947     0.91967
# mean_test_fbeta                       0.934545   0.934545    0.934385
# std_test_fbeta                       0.0060448  0.0060448  0.00582127
# mean_train_recall                     0.952639   0.952518    0.952939
# mean_train_precision                  0.922542   0.922506    0.922296
# mean_train_fbeta                      0.937348   0.937271    0.937366
# param_classifier__class_weight        balanced   balanced    balanced
# param_classifier__max_depth                  5          5           5
# param_classifier__max_features            None       None        None
# param_classifier__min_samples_split          2          5           2
# param_classifier__n_estimators             300        300         100
# param_classifier__random_state               1          1           1
# mean_fit_time                          6.57605    7.40583     2.16802
#
#                                              23          20          22  \
# mean_test_recall                       0.949665    0.949394    0.949394
# mean_test_precision                    0.919436    0.919409    0.919402
# mean_test_fbeta                        0.934258    0.934118    0.934116
# std_test_fbeta                       0.00587175  0.00580523  0.00564097
# mean_train_recall                      0.952308    0.952849    0.952699
# mean_train_precision                   0.922383    0.922263    0.922144
# mean_train_fbeta                       0.937106    0.937305    0.937171
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                   5           5           5
# param_classifier__max_features             None        None        None
# param_classifier__min_samples_split           7           5           7
# param_classifier__n_estimators              300         100         100
# param_classifier__random_state                1           1           1
# mean_fit_time                           7.16065     2.17336     2.24623
#
#                                              16          14          12  \
# mean_test_recall                       0.939099    0.939913    0.940182
# mean_test_precision                    0.912006    0.910318    0.908933
# mean_test_fbeta                        0.925255    0.924811    0.924213
# std_test_fbeta                       0.00845343  0.00799346  0.00793962
# mean_train_recall                      0.940851    0.941663    0.941753
# mean_train_precision                    0.91412    0.914235    0.913577
# mean_train_fbeta                       0.927284     0.92774    0.927444
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                   5           5           5
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           7           5           2
# param_classifier__n_estimators              100         100         100
# param_classifier__random_state                1           1           1
# mean_fit_time                           1.04946     1.03663     1.16166
#
#                                              13          17          15  \
# mean_test_recall                        0.93856    0.937206    0.937478
# mean_test_precision                    0.910375    0.911492    0.910532
# mean_test_fbeta                        0.924204    0.924104    0.923753
# std_test_fbeta                       0.00715578  0.00654983  0.00701933
# mean_train_recall                      0.940069    0.940099    0.939979
# mean_train_precision                   0.914096    0.913912    0.914142
# mean_train_fbeta                       0.926899    0.926819    0.926879
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                   5           5           5
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           2           7           5
# param_classifier__n_estimators              300         300         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           3.15318     3.06871     3.19067
#
#                                              4           0           2   \
# mean_test_recall                       0.937746    0.937746    0.937746
# mean_test_precision                    0.900717    0.900717    0.900717
# mean_test_fbeta                        0.918777    0.918777    0.918777
# std_test_fbeta                       0.00936433  0.00936433  0.00936433
# mean_train_recall                      0.938836    0.938836    0.938836
# mean_train_precision                   0.900448    0.900448    0.900448
# mean_train_fbeta                       0.919238    0.919238    0.919238
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                   3           3           3
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           7           2           5
# param_classifier__n_estimators              100         100         100
# param_classifier__random_state                1           1           1
# mean_fit_time                          0.820847    0.840526      0.9002
#
#                                              3           5           1   \
# mean_test_recall                       0.931794    0.931794    0.931794
# mean_test_precision                    0.905254    0.905254    0.905254
# mean_test_fbeta                        0.918279    0.918279    0.918279
# std_test_fbeta                       0.00852239  0.00852239  0.00852239
# mean_train_recall                      0.932551    0.932551    0.932551
# mean_train_precision                   0.906126    0.906126    0.906126
# mean_train_fbeta                       0.919147    0.919147    0.919147
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                   3           3           3
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           5           7           2
# param_classifier__n_estimators              300         300         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           2.26627     2.33043      2.5186
#
#                                              9           7           11  \
# mean_test_recall                       0.916638    0.916638    0.916638
# mean_test_precision                    0.914817    0.914817    0.914817
# mean_test_fbeta                        0.915663    0.915663    0.915663
# std_test_fbeta                       0.00803728  0.00803728  0.00803728
# mean_train_recall                      0.918087    0.918087    0.918087
# mean_train_precision                   0.915313    0.915313    0.915313
# mean_train_fbeta                       0.916696    0.916696    0.916696
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                   3           3           3
# param_classifier__max_features             None        None        None
# param_classifier__min_samples_split           5           2           7
# param_classifier__n_estimators              300         300         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           4.82869     5.42662     5.55935
#
#                                             6          10         8
# mean_test_recall                      0.916367   0.916367   0.916367
# mean_test_precision                   0.914561   0.914561   0.914561
# mean_test_fbeta                       0.915394   0.915394   0.915394
# std_test_fbeta                       0.0079135  0.0079135  0.0079135
# mean_train_recall                     0.918118   0.918118   0.918118
# mean_train_precision                  0.915012   0.915012   0.915012
# mean_train_fbeta                      0.916561   0.916561   0.916561
# param_classifier__class_weight        balanced   balanced   balanced
# param_classifier__max_depth                  3          3          3
# param_classifier__max_features            None       None       None
# param_classifier__min_samples_split          2          7          5
# param_classifier__n_estimators             100        100        100
# param_classifier__random_state               1          1          1
# mean_fit_time                          1.55906    1.57473    1.68529
#                            max       min
# mean_test_recall      0.965092  0.916367
# mean_test_precision   0.955628  0.900717
# mean_test_fbeta       0.956201  0.915394
# std_test_fbeta        0.009364  0.003483
# mean_train_recall     1.000000  0.918087
# mean_train_precision  0.999459  0.900448
# mean_train_fbeta      0.999729  0.916561

# %% [markdown]
# ## Add easy spaCy features

# %%
[i for i in documents[19]]
# Out:
# [Item, 4, .]

# %%
documents[19].to_array(
            ["IS_STOP", "IS_UPPER", "IS_LOWER", "IS_DIGIT", "IS_PUNCT", "IS_ASCII"]
        ).sum(axis=0) / len(documents[19])
# Out:
# array([0.        , 0.        , 0.        , 0.33333333, 0.33333333,
#        1.        ])

# %%
# TODO: do it on the dataframe directly?
feature_names = ["IS_STOP", "IS_UPPER", "IS_LOWER", "IS_DIGIT", "IS_PUNCT","IS_ASCII"]
features = np.zeros((len(documents), len(feature_names)))
for idx, doc in enumerate(tqdm(documents)):
    features[idx, :] = doc.to_array(feature_names).sum(axis=0) / len(doc)
for idx, feature in enumerate(feature_names):
    df[feature.lower()] = features[:, idx]
# Out:
# HBox(children=(IntProgress(value=0, max=14215), HTML(value='')))

# %%
df.head(15)
# Out:
#                                                  text  is_bold  is_italic  \
# 0   NOTES TO THE ACCOUNTS FOR THE 52 WEEK PERIOD E...     True      False
# 1                              DERIVATIVE INSTRUMENTS    False      False
# 2                                                  -6    False      False
# 3   The following performance graph and related in...    False      False
# 4   Typical service offerings include supply chain...    False      False
# 5   A substantial portion of contract and administ...    False      False
# 6   PMA applications must be supported by valid sc...    False      False
# 7   We are subject to healthcare regulation and en...    False      False
# 8   Against the outlined challenges, developing ec...    False      False
# 9   The results of our operations are dependent on...    False      False
# 10                                                       False      False
# 11  Following a reduction in the Bank of England B...    False      False
# 12  The Company has two equity participation plans...    False      False
# 13  The occurrence of a catastrophic disaster or o...     True      False
# 14                                                       False      False
#
#     is_underlined   left  right          top       bottom  label  char_length  \
# 0           False   49.5  544.0    67.300000    96.100000      1           66
# 1           False   41.5  140.2    49.000000    54.700000      1           22
# 2           False  113.5  122.2   409.300000   414.900000      0            2
# 3           False  112.9  706.9   339.000000   360.300000      0          525
# 4           False   33.1  808.5   328.200000   369.900000      0         1061
# 5           False   33.1  808.6   165.500000   189.200000      0          533
# 6           False  112.4  724.9   261.400000   336.200000      0         1926
# 7           False   33.1  808.3    49.000000    64.300000      0          326
# 8           False   68.0  541.4   561.000000   615.900000      0          482
# 9           False   43.9  807.9   110.700000   125.500000      0          433
# 10          False   73.3   76.1   116.300000   121.900000      0            1
# 11          False   42.6  279.8  1175.837194  1204.737194      0          159
# 12          False   61.9  769.5    56.300000    81.100000      0          564
# 13          False   33.1  676.9   193.300000   198.800000      1          198
# 14          False   43.3   46.1    77.300000    82.900000      0            1
#
#     token_length   is_stop  is_upper  is_lower  is_digit  is_punct  is_ascii
# 0             13  0.000000  0.769231  0.000000  0.230769  0.000000       1.0
# 1              2  0.000000  1.000000  0.000000  0.000000  0.000000       1.0
# 2              1  0.000000  0.000000  0.000000  0.000000  0.000000       1.0
# 3             99  0.424242  0.010101  0.666667  0.030303  0.131313       1.0
# 4            164  0.146341  0.018293  0.725610  0.006098  0.189024       1.0
# 5             90  0.388889  0.011111  0.866667  0.011111  0.044444       1.0
# 6            335  0.402985  0.068657  0.805970  0.000000  0.098507       1.0
# 7             57  0.315789  0.000000  0.807018  0.000000  0.157895       1.0
# 8             78  0.256410  0.000000  0.820513  0.000000  0.141026       1.0
# 9             70  0.285714  0.000000  0.814286  0.000000  0.142857       1.0
# 10             1  0.000000  0.000000  0.000000  0.000000  0.000000       1.0
# 11            29  0.413793  0.000000  0.689655  0.034483  0.034483       1.0
# 12           105  0.295238  0.000000  0.695238  0.028571  0.171429       1.0
# 13            34  0.470588  0.000000  0.882353  0.000000  0.088235       1.0
# 14             1  0.000000  0.000000  0.000000  0.000000  0.000000       1.0

# %%
pipe = Pipeline([
    # the reduce_dim stage is populated by the param_grid
    ('scaling', MinMaxScaler()),
    ('classifier', RandomForestClassifier()),
])
param_grid = {
        "n_estimators": [100, 300],
        "min_samples_split": [2, 5, 7],
        "max_features": ["sqrt", None],
        "max_depth": [10, 25, 35],
        "random_state": [1],
        "class_weight": ["balanced"]
    }
param_grid = {f"classifier__{key}": value for key, value in param_grid.items()}
result = grid_search_algo(
    pipe, param_grid, X.drop("text", axis=1), y, scoring=scoring, refit=False,
)
analyse_grid_search(result)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=3)]: Done 360 out of 360 | elapsed: 13.8min finished
#                                              24          21          33  \
# mean_test_recall                       0.949936    0.960215    0.960215
# mean_test_precision                    0.956814    0.946632    0.946632
# mean_test_fbeta                        0.953293    0.953286    0.953286
# std_test_fbeta                       0.00597357  0.00606831  0.00606831
# mean_train_recall                             1    0.999008    0.999008
# mean_train_precision                   0.999459    0.986959    0.986959
# mean_train_fbeta                       0.999729    0.992946    0.992946
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  35          25          35
# param_classifier__max_features             sqrt        None        None
# param_classifier__min_samples_split           2           5           5
# param_classifier__n_estimators              100         300         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           1.64391     11.5711      11.707
#
#                                              19          31          12  \
# mean_test_recall                       0.953989    0.953989    0.949397
# mean_test_precision                    0.952594    0.952594    0.956769
# mean_test_fbeta                        0.953234    0.953234    0.952998
# std_test_fbeta                       0.00621346  0.00621346  0.00680619
# mean_train_recall                             1           1           1
# mean_train_precision                   0.999459    0.999459    0.999459
# mean_train_fbeta                       0.999729    0.999729    0.999729
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          35          25
# param_classifier__max_features             None        None        sqrt
# param_classifier__min_samples_split           2           2           2
# param_classifier__n_estimators              300         300         100
# param_classifier__random_state                1           1           1
# mean_fit_time                           11.5714     11.6995     1.65888
#
#                                              18          30          35  \
# mean_test_recall                       0.953179    0.953179    0.963193
# mean_test_precision                    0.952842    0.952584    0.942753
# mean_test_fbeta                        0.952945    0.952816    0.952781
# std_test_fbeta                       0.00638036  0.00645512  0.00624036
# mean_train_recall                       0.99997     0.99997     0.99594
# mean_train_precision                   0.999459    0.999459    0.976704
# mean_train_fbeta                       0.999714    0.999714    0.986228
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          35          35
# param_classifier__max_features             None        None        None
# param_classifier__min_samples_split           2           2           7
# param_classifier__n_estimators              100         100         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           3.89044     3.87401     11.2726
#
#                                              23          13          25  \
# mean_test_recall                       0.963193    0.950478    0.949936
# mean_test_precision                    0.942753    0.954761     0.95476
# mean_test_fbeta                        0.952781    0.952539    0.952257
# std_test_fbeta                       0.00624036  0.00674059  0.00666633
# mean_train_recall                       0.99594           1           1
# mean_train_precision                   0.976675    0.999459    0.999459
# mean_train_fbeta                       0.986213    0.999729    0.999729
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          25          35
# param_classifier__max_features             None        sqrt        sqrt
# param_classifier__min_samples_split           7           2           2
# param_classifier__n_estimators              300         300         300
# param_classifier__random_state                1           1           1
# mean_fit_time                            11.607     4.81455     4.97153
#
#                                              22          34          32  \
# mean_test_recall                       0.962109    0.962109    0.958318
# mean_test_precision                    0.941685    0.941685     0.94529
# mean_test_fbeta                        0.951714    0.951714    0.951666
# std_test_fbeta                       0.00660139  0.00660139  0.00708831
# mean_train_recall                       0.99564     0.99564    0.998286
# mean_train_precision                   0.976409    0.976409    0.986539
# mean_train_fbeta                        0.98593     0.98593    0.992378
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          35          35
# param_classifier__max_features             None        None        None
# param_classifier__min_samples_split           7           7           5
# param_classifier__n_estimators              100         100         100
# param_classifier__random_state                1           1           1
# mean_fit_time                           3.87232      4.8028     3.86639
#
#                                              20         26          27  \
# mean_test_recall                       0.958318    0.95589    0.956432
# mean_test_precision                     0.94529     0.9471    0.946125
# mean_test_fbeta                        0.951666   0.951401    0.951179
# std_test_fbeta                       0.00708831  0.0076748  0.00818944
# mean_train_recall                      0.998286   0.998557    0.999338
# mean_train_precision                    0.98651   0.981934    0.982267
# mean_train_fbeta                       0.992363   0.990175    0.990729
# param_classifier__class_weight         balanced   balanced    balanced
# param_classifier__max_depth                  25         35          35
# param_classifier__max_features             None       sqrt        sqrt
# param_classifier__min_samples_split           5          5           5
# param_classifier__n_estimators              100        100         300
# param_classifier__random_state                1          1           1
# mean_fit_time                            4.1183    1.63256     4.82931
#
#                                              14          16          29  \
# mean_test_recall                       0.955349    0.959139    0.958599
# mean_test_precision                    0.946563    0.942751    0.943243
# mean_test_fbeta                        0.950865      0.9508    0.950777
# std_test_fbeta                       0.00779449  0.00805927  0.00842411
# mean_train_recall                      0.998527     0.99561    0.996602
# mean_train_precision                   0.981905    0.970371    0.970314
# mean_train_fbeta                       0.990145    0.982828    0.983282
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          25          35
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           5           7           7
# param_classifier__n_estimators              100         100         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           1.61052     1.61214     4.88074
#
#                                              17          15          28  \
# mean_test_recall                        0.95887    0.955621    0.958328
# mean_test_precision                    0.942738    0.945579     0.94244
# mean_test_fbeta                        0.950659    0.950499    0.950247
# std_test_fbeta                       0.00874865  0.00803775  0.00813505
# mean_train_recall                      0.996782    0.999369      0.9957
# mean_train_precision                    0.97012    0.982122    0.970459
# mean_train_fbeta                        0.98327     0.99067    0.982917
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  25          25          35
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           7           5           7
# param_classifier__n_estimators              300         300         100
# param_classifier__random_state                1           1           1
# mean_fit_time                            4.8269     4.84521     1.65743
#
#                                              6          7           11  \
# mean_test_recall                        0.96049   0.960219    0.962384
# mean_test_precision                    0.939319   0.938791    0.935472
# mean_test_fbeta                         0.94972   0.949317    0.948674
# std_test_fbeta                       0.00878523  0.0084191  0.00788064
# mean_train_recall                      0.980785   0.980665    0.977597
# mean_train_precision                     0.9591   0.958672    0.951534
# mean_train_fbeta                        0.96982   0.969542    0.964388
# param_classifier__class_weight         balanced   balanced    balanced
# param_classifier__max_depth                  10         10          10
# param_classifier__max_features             None       None        None
# param_classifier__min_samples_split           2          2           7
# param_classifier__n_estimators              100        300         300
# param_classifier__random_state                1          1           1
# mean_fit_time                           3.43846     10.581     10.8865
#
#                                              9           8          10  \
# mean_test_recall                       0.961302    0.961573   0.961302
# mean_test_precision                    0.936152     0.93545   0.934909
# mean_test_fbeta                         0.94849    0.948264   0.947858
# std_test_fbeta                       0.00797419  0.00905522  0.0084119
# mean_train_recall                      0.979191    0.978951   0.977567
# mean_train_precision                   0.954677    0.954891   0.951726
# mean_train_fbeta                       0.966778     0.96677   0.964473
# param_classifier__class_weight         balanced    balanced   balanced
# param_classifier__max_depth                  10          10         10
# param_classifier__max_features             None        None       None
# param_classifier__min_samples_split           5           5          7
# param_classifier__n_estimators              300         100        100
# param_classifier__random_state                1           1          1
# mean_fit_time                            10.321     3.48215    3.54829
#
#                                              0           1           3   \
# mean_test_recall                       0.959681     0.95914    0.959411
# mean_test_precision                    0.932049    0.932495    0.929818
# mean_test_fbeta                        0.945619    0.945592    0.944339
# std_test_fbeta                       0.00826713  0.00896235  0.00859575
# mean_train_recall                      0.972756    0.973087    0.971553
# mean_train_precision                   0.946073    0.946007    0.942671
# mean_train_fbeta                       0.959228    0.959355    0.956893
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  10          10          10
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           2           2           5
# param_classifier__n_estimators              100         300         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           1.48545     4.58314     4.73137
#
#                                              2           4           5
# mean_test_recall                       0.959142    0.958329     0.95914
# mean_test_precision                    0.929778    0.929495    0.928098
# mean_test_fbeta                         0.94419    0.943655     0.94332
# std_test_fbeta                       0.00800257  0.00861499  0.00848844
# mean_train_recall                      0.971884    0.970771    0.971463
# mean_train_precision                   0.942113    0.940347     0.94077
# mean_train_fbeta                       0.956766    0.955316     0.95587
# param_classifier__class_weight         balanced    balanced    balanced
# param_classifier__max_depth                  10          10          10
# param_classifier__max_features             sqrt        sqrt        sqrt
# param_classifier__min_samples_split           5           7           7
# param_classifier__n_estimators              100         100         300
# param_classifier__random_state                1           1           1
# mean_fit_time                           1.46944     1.79373     4.66029
#                            max       min
# mean_test_recall      0.963193  0.949397
# mean_test_precision   0.956814  0.928098
# mean_test_fbeta       0.953293  0.943320
# std_test_fbeta        0.009055  0.005974
# mean_train_recall     1.000000  0.970771
# mean_train_precision  0.999459  0.940347
# mean_train_fbeta      0.999729  0.955316

# %% [markdown]
# TODO:
# * More data analyisis and preprocessing:
#   * if only punct probably never title
#   * if only numbers? for sure not if negative
#   * remove those cases from training and **bypass** mlpipeline if so
#   * removing stop words won't help as titles are many times stop words
# * Add TF-IDF features (+PCA?)
# * Add LDA features
# * Nested CV
# * add spaCy features
#   * NER?
# * two-stage classifier: https://www.aclweb.org/anthology/I13-1114
